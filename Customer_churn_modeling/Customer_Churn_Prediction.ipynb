# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("Churn_Modelling.csv")

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
print(df.shape)
# Out:
# (10000, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df['Exited'].value_counts()
# Out:
# Exited
# 0    7963
# 1    2037
# Name: count, dtype: int64

# %%
df['Geography'].value_counts()
# Out:
# Geography
# France     5014
# Germany    2509
# Spain      2477
# Name: count, dtype: int64

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male      5457
# Female    4543
# Name: count, dtype: int64

# %%
df.drop(columns = ['RowNumber','CustomerId','Surname'],inplace = True, axis = 1)

# %%
df.head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
# 3          699    France  Female   39       1       0.00              2
# 4          850     Spain  Female   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0          1               1        101348.88       1
# 1          0               1        112542.58       0
# 2          1               0        113931.57       1
# 3          0               0         93826.63       0
# 4          1               1         79084.10       0

# %%
df = pd.get_dummies(df,columns = ['Geography','Gender'],drop_first = True,dtype = int)

# %%
df
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619   42       2       0.00              1          1
# 1             608   41       1   83807.86              1          0
# 2             502   42       8  159660.80              3          1
# 3             699   39       1       0.00              2          0
# 4             850   43       2  125510.82              1          1
# ...           ...  ...     ...        ...            ...        ...
# 9995          771   39       5       0.00              2          1
# 9996          516   35      10   57369.61              1          1
# 9997          709   36       7       0.00              1          0
# 9998          772   42       3   75075.31              2          1
# 9999          792   28       4  130142.79              1          1
#
#       IsActiveMember  EstimatedSalary  Exited  Geography_Germany  \
# 0                  1        101348.88       1                  0
# 1                  1        112542.58       0                  0
# 2                  0        113931.57       1                  0
# 3                  0         93826.63       0                  0
# 4                  1         79084.10       0                  0
# ...              ...              ...     ...                ...
# 9995               0         96270.64       0                  0
# 9996               1        101699.77       0                  0
# 9997               1         42085.58       1                  0
# 9998               0         92888.52       1                  1
# 9999               0         38190.78       0                  0
#
#       Geography_Spain  Gender_Male
# 0                   0            0
# 1                   1            0
# 2                   0            0
# 3                   0            0
# 4                   1            0
# ...               ...          ...
# 9995                0            1
# 9996                0            1
# 9997                0            0
# 9998                0            1
# 9999                0            0
#
# [10000 rows x 12 columns]

# %%
X = df.drop(columns = ['Exited'])
y = df['Exited']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 1)

# %%
X
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619   42       2       0.00              1          1
# 1             608   41       1   83807.86              1          0
# 2             502   42       8  159660.80              3          1
# 3             699   39       1       0.00              2          0
# 4             850   43       2  125510.82              1          1
# ...           ...  ...     ...        ...            ...        ...
# 9995          771   39       5       0.00              2          1
# 9996          516   35      10   57369.61              1          1
# 9997          709   36       7       0.00              1          0
# 9998          772   42       3   75075.31              2          1
# 9999          792   28       4  130142.79              1          1
#
#       IsActiveMember  EstimatedSalary  Geography_Germany  Geography_Spain  \
# 0                  1        101348.88                  0                0
# 1                  1        112542.58                  0                1
# 2                  0        113931.57                  0                0
# 3                  0         93826.63                  0                0
# 4                  1         79084.10                  0                1
# ...              ...              ...                ...              ...
# 9995               0         96270.64                  0                0
# 9996               1        101699.77                  0                0
# 9997               1         42085.58                  0                0
# 9998               0         92888.52                  1                0
# 9999               0         38190.78                  0                0
#
#       Gender_Male
# 0               0
# 1               0
# 2               0
# 3               0
# 4               0
# ...           ...
# 9995            1
# 9996            1
# 9997            0
# 9998            1
# 9999            0
#
# [10000 rows x 11 columns]

# %%
X_train.shape
# Out:
# (8000, 11)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
import tensorflow
from tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense

# %%
model = Sequential()

model.add(Dense(11, activation = 'relu',input_dim = 11))
model.add(Dense(11, activation = 'relu'))
model.add(Dense(1, activation = 'sigmoid'))
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 11)                  │             132 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 11)                  │             132 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 1)                   │              12 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 276 (1.08 KB)
#  Trainable params: 276 (1.08 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(loss = 'binary_crossentropy',optimizer = 'Adam', metrics = ['accuracy'])

# %%
history = model.fit(X_train_scaled, y_train, epochs = 100, validation_split = 0.2)
# Out:
# Epoch 1/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.7261 - loss: 0.5950 - val_accuracy: 0.7975 - val_loss: 0.5096
# Epoch 2/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7962 - loss: 0.4841 - val_accuracy: 0.7969 - val_loss: 0.4651
# Epoch 3/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8052 - loss: 0.4457 - val_accuracy: 0.8081 - val_loss: 0.4375
# Epoch 4/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8181 - loss: 0.4138 - val_accuracy: 0.8150 - val_loss: 0.4178
# Epoch 5/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8241 - loss: 0.4056 - val_accuracy: 0.8294 - val_loss: 0.4047
# Epoch 6/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8378 - loss: 0.3927 - val_accuracy: 0.8375 - val_loss: 0.3919
# Epoch 7/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8422 - loss: 0.3851 - val_accuracy: 0.8462 - val_loss: 0.3803
# Epoch 8/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8503 - loss: 0.3684 - val_accuracy: 0.8487 - val_loss: 0.3696
# Epoch 9/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8581 - loss: 0.3565 - val_accuracy: 0.8512 - val_loss: 0.3605
# Epoch 10/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8551 - loss: 0.3599 - val_accuracy: 0.8519 - val_loss: 0.3576
# Epoch 11/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8537 - loss: 0.3490 - val_accuracy: 0.8525 - val_loss: 0.3547
# Epoch 12/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8527 - loss: 0.3432 - val_accuracy: 0.8556 - val_loss: 0.3501
# Epoch 13/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8557 - loss: 0.3444 - val_accuracy: 0.8550 - val_loss: 0.3491
# Epoch 14/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8596 - loss: 0.3422 - val_accuracy: 0.8550 - val_loss: 0.3474
# Epoch 15/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8553 - loss: 0.3404 - val_accuracy: 0.8531 - val_loss: 0.3488
# Epoch 16/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8577 - loss: 0.3402 - val_accuracy: 0.8531 - val_loss: 0.3452
# Epoch 17/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8603 - loss: 0.3427 - val_accuracy: 0.8506 - val_loss: 0.3461
# Epoch 18/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8615 - loss: 0.3416 - val_accuracy: 0.8525 - val_loss: 0.3459
# Epoch 19/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8622 - loss: 0.3370 - val_accuracy: 0.8500 - val_loss: 0.3484
# Epoch 20/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8575 - loss: 0.3379 - val_accuracy: 0.8500 - val_loss: 0.3451
# Epoch 21/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8547 - loss: 0.3391 - val_accuracy: 0.8525 - val_loss: 0.3440
# Epoch 22/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8632 - loss: 0.3367 - val_accuracy: 0.8519 - val_loss: 0.3444
# Epoch 23/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8642 - loss: 0.3248 - val_accuracy: 0.8525 - val_loss: 0.3456
# Epoch 24/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8639 - loss: 0.3302 - val_accuracy: 0.8494 - val_loss: 0.3438
# Epoch 25/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8631 - loss: 0.3327 - val_accuracy: 0.8519 - val_loss: 0.3438
# Epoch 26/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8758 - loss: 0.3122 - val_accuracy: 0.8581 - val_loss: 0.3432
# Epoch 27/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8563 - loss: 0.3387 - val_accuracy: 0.8506 - val_loss: 0.3444
# Epoch 28/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8616 - loss: 0.3314 - val_accuracy: 0.8519 - val_loss: 0.3428
# Epoch 29/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8605 - loss: 0.3395 - val_accuracy: 0.8544 - val_loss: 0.3432
# Epoch 30/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8606 - loss: 0.3369 - val_accuracy: 0.8537 - val_loss: 0.3417
# Epoch 31/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8622 - loss: 0.3359 - val_accuracy: 0.8569 - val_loss: 0.3423
# Epoch 32/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8684 - loss: 0.3279 - val_accuracy: 0.8525 - val_loss: 0.3424
# Epoch 33/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8542 - loss: 0.3412 - val_accuracy: 0.8525 - val_loss: 0.3414
# Epoch 34/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8752 - loss: 0.3058 - val_accuracy: 0.8562 - val_loss: 0.3414
# Epoch 35/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8689 - loss: 0.3213 - val_accuracy: 0.8531 - val_loss: 0.3436
# Epoch 36/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8595 - loss: 0.3321 - val_accuracy: 0.8500 - val_loss: 0.3447
# Epoch 37/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8652 - loss: 0.3275 - val_accuracy: 0.8587 - val_loss: 0.3423
# Epoch 38/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8638 - loss: 0.3294 - val_accuracy: 0.8544 - val_loss: 0.3423
# Epoch 39/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8564 - loss: 0.3368 - val_accuracy: 0.8556 - val_loss: 0.3405
# Epoch 40/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8776 - loss: 0.3068 - val_accuracy: 0.8556 - val_loss: 0.3426
# Epoch 41/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8621 - loss: 0.3251 - val_accuracy: 0.8556 - val_loss: 0.3406
# Epoch 42/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8700 - loss: 0.3238 - val_accuracy: 0.8531 - val_loss: 0.3420
# Epoch 43/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8745 - loss: 0.3191 - val_accuracy: 0.8525 - val_loss: 0.3410
# Epoch 44/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8658 - loss: 0.3268 - val_accuracy: 0.8531 - val_loss: 0.3423
# Epoch 45/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8688 - loss: 0.3251 - val_accuracy: 0.8550 - val_loss: 0.3431
# Epoch 46/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8709 - loss: 0.3161 - val_accuracy: 0.8544 - val_loss: 0.3427
# Epoch 47/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8643 - loss: 0.3289 - val_accuracy: 0.8525 - val_loss: 0.3423
# Epoch 48/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8666 - loss: 0.3262 - val_accuracy: 0.8556 - val_loss: 0.3428
# Epoch 49/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8712 - loss: 0.3181 - val_accuracy: 0.8556 - val_loss: 0.3407
# Epoch 50/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8629 - loss: 0.3397 - val_accuracy: 0.8531 - val_loss: 0.3417
# Epoch 51/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8727 - loss: 0.3206 - val_accuracy: 0.8556 - val_loss: 0.3405
# Epoch 52/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8650 - loss: 0.3299 - val_accuracy: 0.8569 - val_loss: 0.3404
# Epoch 53/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8587 - loss: 0.3368 - val_accuracy: 0.8531 - val_loss: 0.3445
# Epoch 54/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8708 - loss: 0.3178 - val_accuracy: 0.8575 - val_loss: 0.3414
# Epoch 55/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8613 - loss: 0.3288 - val_accuracy: 0.8525 - val_loss: 0.3409
# Epoch 56/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8616 - loss: 0.3349 - val_accuracy: 0.8562 - val_loss: 0.3417
# Epoch 57/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8695 - loss: 0.3305 - val_accuracy: 0.8556 - val_loss: 0.3410
# Epoch 58/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8659 - loss: 0.3209 - val_accuracy: 0.8550 - val_loss: 0.3419
# Epoch 59/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8688 - loss: 0.3135 - val_accuracy: 0.8562 - val_loss: 0.3409
# Epoch 60/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8703 - loss: 0.3237 - val_accuracy: 0.8556 - val_loss: 0.3410
# Epoch 61/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8625 - loss: 0.3325 - val_accuracy: 0.8575 - val_loss: 0.3411
# Epoch 62/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8647 - loss: 0.3281 - val_accuracy: 0.8562 - val_loss: 0.3416
# Epoch 63/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8774 - loss: 0.3156 - val_accuracy: 0.8556 - val_loss: 0.3410
# Epoch 64/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8583 - loss: 0.3298 - val_accuracy: 0.8556 - val_loss: 0.3418
# Epoch 65/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8662 - loss: 0.3210 - val_accuracy: 0.8594 - val_loss: 0.3410
# Epoch 66/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8691 - loss: 0.3202 - val_accuracy: 0.8575 - val_loss: 0.3403
# Epoch 67/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8647 - loss: 0.3293 - val_accuracy: 0.8562 - val_loss: 0.3399
# Epoch 68/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8632 - loss: 0.3329 - val_accuracy: 0.8562 - val_loss: 0.3417
# Epoch 69/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8660 - loss: 0.3260 - val_accuracy: 0.8594 - val_loss: 0.3411
# Epoch 70/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8692 - loss: 0.3241 - val_accuracy: 0.8556 - val_loss: 0.3413
# Epoch 71/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8657 - loss: 0.3178 - val_accuracy: 0.8575 - val_loss: 0.3421
# Epoch 72/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8640 - loss: 0.3140 - val_accuracy: 0.8587 - val_loss: 0.3416
# Epoch 73/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8690 - loss: 0.3306 - val_accuracy: 0.8556 - val_loss: 0.3410
# Epoch 74/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8623 - loss: 0.3291 - val_accuracy: 0.8575 - val_loss: 0.3408
# Epoch 75/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8627 - loss: 0.3205 - val_accuracy: 0.8581 - val_loss: 0.3412
# Epoch 76/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8694 - loss: 0.3282 - val_accuracy: 0.8550 - val_loss: 0.3404
# Epoch 77/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8648 - loss: 0.3170 - val_accuracy: 0.8531 - val_loss: 0.3408
# Epoch 78/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8701 - loss: 0.3188 - val_accuracy: 0.8556 - val_loss: 0.3415
# Epoch 79/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8592 - loss: 0.3367 - val_accuracy: 0.8581 - val_loss: 0.3402
# Epoch 80/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8668 - loss: 0.3256 - val_accuracy: 0.8562 - val_loss: 0.3418
# Epoch 81/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8702 - loss: 0.3167 - val_accuracy: 0.8575 - val_loss: 0.3398
# Epoch 82/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8670 - loss: 0.3259 - val_accuracy: 0.8575 - val_loss: 0.3403
# Epoch 83/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8735 - loss: 0.3149 - val_accuracy: 0.8562 - val_loss: 0.3402
# Epoch 84/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8627 - loss: 0.3313 - val_accuracy: 0.8562 - val_loss: 0.3404
# Epoch 85/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8716 - loss: 0.3145 - val_accuracy: 0.8556 - val_loss: 0.3402
# Epoch 86/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8657 - loss: 0.3165 - val_accuracy: 0.8562 - val_loss: 0.3411
# Epoch 87/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8705 - loss: 0.3131 - val_accuracy: 0.8556 - val_loss: 0.3384
# Epoch 88/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8634 - loss: 0.3377 - val_accuracy: 0.8562 - val_loss: 0.3400
# Epoch 89/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8693 - loss: 0.3219 - val_accuracy: 0.8550 - val_loss: 0.3394
# Epoch 90/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8696 - loss: 0.3077 - val_accuracy: 0.8575 - val_loss: 0.3402
# Epoch 91/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8647 - loss: 0.3293 - val_accuracy: 0.8556 - val_loss: 0.3402
# Epoch 92/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8696 - loss: 0.3209 - val_accuracy: 0.8544 - val_loss: 0.3412
# Epoch 93/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8650 - loss: 0.3326 - val_accuracy: 0.8556 - val_loss: 0.3399
# Epoch 94/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8693 - loss: 0.3216 - val_accuracy: 0.8556 - val_loss: 0.3412
# Epoch 95/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8669 - loss: 0.3209 - val_accuracy: 0.8556 - val_loss: 0.3411
# Epoch 96/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8626 - loss: 0.3234 - val_accuracy: 0.8531 - val_loss: 0.3428
# Epoch 97/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8620 - loss: 0.3258 - val_accuracy: 0.8550 - val_loss: 0.3414
# Epoch 98/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8701 - loss: 0.3218 - val_accuracy: 0.8562 - val_loss: 0.3401
# Epoch 99/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8659 - loss: 0.3235 - val_accuracy: 0.8550 - val_loss: 0.3402
# Epoch 100/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8722 - loss: 0.3127 - val_accuracy: 0.8569 - val_loss: 0.3397

# %%
model.layers[0].get_weights()
# Out:
# [array([[-3.68758440e-02, -5.82014248e-02,  3.97742204e-02,
#          -1.83601510e-02, -6.63537830e-02,  8.38832855e-02,
#           7.67706335e-02,  3.59860845e-02,  1.03417009e-01,
#          -6.27039699e-04, -2.96039861e-02],
#         [-1.28682971e-01, -5.62677026e-01,  3.11147809e-01,
#          -2.17462793e-01,  7.99036860e-01,  3.27780455e-01,
#           2.77142525e-01, -5.93242705e-01,  1.67023748e-01,
#          -1.00142205e+00,  6.00221716e-02],
#         [ 1.14211604e-01,  6.32887706e-02, -8.01337510e-02,
#          -2.41750643e-01,  2.25749955e-01,  8.67199153e-02,
#           1.92471713e-01,  2.62119267e-02,  5.54520674e-02,
#           5.35042360e-02,  7.14056892e-03],
#         [-7.15111077e-01,  2.44583383e-01, -8.99927244e-02,
#          -1.57249019e-01,  6.88264742e-02,  3.10363676e-02,
#          -5.33332944e-01, -5.45610413e-02,  3.91300291e-01,
#           6.69640660e-01, -8.19131494e-01],
#         [ 3.21058184e-02, -3.68659288e-01, -3.20766836e-01,
#           1.08603433e-01, -2.58189708e-01,  1.26487720e+00,
#           1.32354692e-01, -3.32480930e-02, -1.13008404e+00,
#          -3.44191164e-01, -1.22731864e+00],
#         [-3.63232791e-01, -7.66085446e-01,  2.33642720e-02,
#          -2.09199309e-01,  1.43132553e-01,  7.05459639e-02,
#           4.79801506e-01,  1.79668714e-03, -1.47620007e-01,
#           2.00345293e-01,  4.78298543e-03],
#         [ 5.70258796e-01, -6.75559193e-02,  1.02392912e+00,
#          -2.58261144e-01,  6.79803252e-01,  2.29832381e-01,
#           5.03697157e-01, -1.64497435e-01, -7.32641220e-02,
#          -2.30495647e-01,  8.07647854e-02],
#         [-3.73037487e-01,  1.74682423e-01,  2.79314697e-01,
#           3.70933175e-01,  2.23850198e-02,  1.10039432e-02,
#          -1.10984676e-01,  1.30061945e-02,  1.31485432e-01,
#           1.70725092e-01,  1.11064790e-02],
#         [ 2.81368494e-01, -5.77988565e-01,  2.53718406e-01,
#           7.01680481e-01, -1.02580607e-01, -2.24469882e-02,
#          -3.30180079e-01, -4.82894331e-02, -2.62454659e-01,
#           1.51740670e-01,  5.44174194e-01],
#         [ 6.07476890e-01,  5.38977608e-03, -1.21066973e-01,
#           2.59992689e-01,  2.20451996e-01,  3.51402581e-01,
#           1.49524823e-01, -2.41345130e-02,  7.00818002e-02,
#           3.15354913e-01,  9.75676775e-02],
#         [ 1.84788063e-01, -1.17988542e-01, -1.25415280e-01,
#           4.09862012e-01, -1.18228551e-02,  1.23556606e-01,
#           5.84149539e-01,  6.22632727e-02, -4.10056347e-03,
#           1.66228175e-01,  6.01239428e-02]], dtype=float32),
#  array([ 0.50900024,  0.2856009 ,  0.06637966,  0.22758213, -0.7859339 ,
#         -0.01395366,  0.31469417,  0.91491795,  0.04827084, -0.21338113,
#         -0.02200238], dtype=float32)]

# %%
model.layers[1].get_weights()
# Out:
# [array([[-0.6466056 , -0.21678305,  0.3804238 ,  0.3074521 , -0.13428363,
#           0.11471654, -0.07979753, -0.29104316,  0.37280974, -0.45862627,
#           0.4145746 ],
#         [ 0.2888316 ,  0.538043  ,  0.33766463,  0.01812596, -0.30589008,
#           0.14980555,  0.49715152,  0.15593089,  0.10551099, -0.15064858,
#          -0.06793686],
#         [-0.09523618, -0.11710629,  0.41359767, -0.08947012, -0.7775949 ,
#           0.40610805, -0.12100738,  0.4155586 ,  0.38363758,  0.28545272,
#          -0.0238386 ],
#         [ 0.20046201,  0.3121852 ,  0.4030164 ,  0.5833667 ,  0.2200201 ,
#           0.09469787,  0.37712774,  0.23974817,  0.29661983, -0.22482969,
#          -0.05950035],
#         [ 0.65170324, -0.3137659 ,  0.89938927, -0.7766895 , -0.5797376 ,
#           0.07288892, -0.7556321 , -1.108619  ,  0.83627415, -0.4990413 ,
#          -0.57196456],
#         [ 0.7574017 , -0.49297747, -0.03095813,  0.21805844,  0.86805326,
#           0.3187228 ,  0.5063848 , -0.4679615 , -0.06279188,  0.5577713 ,
#           0.3956813 ],
#         [-0.06920275,  0.5320959 ,  0.55265445, -0.29140335, -0.15106979,
#           0.6687171 , -0.5257638 ,  0.29555708, -0.01960063, -0.3015712 ,
#           0.15219824],
#         [-0.2707393 , -0.6291644 ,  0.04885054,  0.38249496, -0.67732036,
#           0.49669826,  0.1579788 ,  0.6918083 ,  0.5338559 , -0.6040261 ,
#          -0.9813314 ],
#         [ 0.08818834, -0.28587526,  0.02157074, -0.1860441 ,  0.57427645,
#           0.07791062, -0.5492899 ,  0.07548446, -0.17156409,  0.81455886,
#           0.63066244],
#         [ 0.3179299 ,  0.41484445,  0.15482047, -0.27085647, -0.44361693,
#           0.06255979, -0.31518403, -0.34468797, -0.23133469, -0.20025554,
#          -0.8702661 ],
#         [-1.5792955 ,  0.46759537,  0.08231579, -0.28743783,  0.243821  ,
#          -1.1446074 , -0.2462108 , -0.34706056,  0.07508817,  0.54716575,
#           0.2560823 ]], dtype=float32),
#  array([-0.01819944, -0.16604649,  0.09187769,  0.24480227, -0.08833923,
#          0.16823839, -0.47174126,  0.5091976 ,  0.22151062,  0.315226  ,
#          0.17891411], dtype=float32)]

# %%
y_log = model.predict(X_test_scaled)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
y_pred = np.where(y_log>0.5,1,0)

# %%
y_pred
# Out:
# array([[0],
#        [0],
#        [0],
#        ...,
#        [0],
#        [0],
#        [0]])

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.8615

# %%
history

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
